# %%
#ques 1
x = 5
y = 3.2
z = "Hello"
print(x+y)
print(z+ "World")
# Out:
# 8.2
# HelloWorld

# %%
#ques 3
result = 10 % 3
print(result)
# Out:
# 1

# %%
#ques 4
x = 7
y = 5
result = 7 != 5
print(result)
# Out:
# True

# %%
#ques 5
x = True
y = False
result = x and y
print(result)
# Out:
# False

# %%
#ques 6
a = 5
a += 3
print(a)
# Out:
# 8

# %%
#ques 7
greeting = "Hello, " + "World!"
print(greeting)
# Out:
# Hello, World!

# %%
#ques 8
repeated = "Python" * 3
print(repeated)
# Out:
# PythonPythonPython

# %%
#ques 9
number = int("42") + 8
print(number)
# Out:
# 50

# %%
#ques 10
result = 17 // 4
print(result)
# Out:
# 4
