# %%
x = 10
print(type(x))
# Out:
# <class 'int'>

# %%
print("hello")
# Out:
# hello

# %%
print("hello")
print('jaipur')
print("rajasthan")
# Out:
# hello
# jaipur
# rajasthan

# %%
x = 10
y = '10'
print(type(x))
print(type(y))
# Out:
# <class 'int'>
# <class 'str'>

# %%
name = 'PRIYA'
address = 'BHIWANI'
print(f'name is {name} address is {address}')
# Out:
# name is PRIYA address is BHIWANI

# %%
a = 10
b = 5
print(a+b)
print(a-b)
print(a/b)
print(a*b)
print(a**b)
print(a//b)
# Out:
# 15
# 5
# 2.0
# 50
# 100000
# 2

# %% [markdown]
# comparison Opreators

# %%
a = 7
b = 5
print(a>b)
print(a<b)
print(a==b)
print(a!=b)
print(a>=b)
print(a<=b)
# Out:
# True
# False
# False
# True
# True
# False

# %% [markdown]
# Assignment Operators

# %%
x = 10
x -= 5
print(x)
# Out:
# 5

# %%
x = 10
x += 5
print(x)
# Out:
# 15

# %%
x = 10
x /= 5
print(x)
# Out:
# 2.0

# %%
x = 10
x *= 5
print(x)
# Out:
# 50

# %%
x = 10
x **= 5
print(x)
# Out:
# 100000

# %%
x = 10
x //= 2
print(x)
# Out:
# 5

# %%
print('''hello
world''')
# Out:
# hello
# world

# %%
a = 5
print('a',super(2) is a**2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-bcf422315d82> in <cell line: 2>()
#       1 a = 5
# ----> 2 print('a',super(2) is a**2)
#
# TypeError: super() argument 1 must be type, not int

# %%
a = True
b = False
print(not(b))
# Out:
# True

# %%
name = 'PRIYA'
'A' in name
# Out:
# True

# %%
'PY' in name
# Out:
# False

# %%
'PR' in name
# Out:
# True
